# %%
import os
import pandas as pd

# %%
def rename_files(directory, action):
    # Get list of files in the directory
    files = os.listdir(directory)
    
    # Initialize counter for renaming
    counter = 351
    
    # Iterate over each file
    for file in files:
        # Construct new file name
        new_name = f"{action}{counter}.csv"  # You can adjust the naming pattern
        
        # Rename the file
        os.rename(os.path.join(directory, file), os.path.join(directory, new_name))
        
        print(f"Renamed '{file}' to '{new_name}'")
        
        # Increment counter
        counter += 1

# Example usage
directory_path = "./actual3/shield/xy"
action = "SHIELD"
rename_files(directory_path, action)
# Out:
# Renamed 'device_5_glove_data_action_1.csv' to 'SHIELD351.csv'
# Renamed 'device_5_glove_data_action_10.csv' to 'SHIELD352.csv'
# Renamed 'device_5_glove_data_action_11.csv' to 'SHIELD353.csv'
# Renamed 'device_5_glove_data_action_12.csv' to 'SHIELD354.csv'
# Renamed 'device_5_glove_data_action_13.csv' to 'SHIELD355.csv'
# Renamed 'device_5_glove_data_action_14.csv' to 'SHIELD356.csv'
# Renamed 'device_5_glove_data_action_15.csv' to 'SHIELD357.csv'
# Renamed 'device_5_glove_data_action_16.csv' to 'SHIELD358.csv'
# Renamed 'device_5_glove_data_action_17.csv' to 'SHIELD359.csv'
# Renamed 'device_5_glove_data_action_18.csv' to 'SHIELD360.csv'
# Renamed 'device_5_glove_data_action_19.csv' to 'SHIELD361.csv'
# Renamed 'device_5_glove_data_action_2.csv' to 'SHIELD362.csv'
# Renamed 'device_5_glove_data_action_20.csv' to 'SHIELD363.csv'
# Renamed 'device_5_glove_data_action_21.csv' to 'SHIELD364.csv'
# Renamed 'device_5_glove_data_action_22.csv' to 'SHIELD365.csv'
# Renamed 'device_5_glove_data_action_23.csv' to 'SHIELD366.csv'
# Renamed 'device_5_glove_data_action_24.csv' to 'SHIELD367.csv'
# Renamed 'device_5_glove_data_action_25.csv' to 'SHIELD368.csv'
# Renamed 'device_5_glove_data_action_26.csv' to 'SHIELD369.csv'
# Renamed 'device_5_glove_data_action_27.csv' to 'SHIELD370.csv'
# Renamed 'device_5_glove_data_action_28.csv' to 'SHIELD371.csv'
# Renamed 'device_5_glove_data_action_29.csv' to 'SHIELD372.csv'
# Renamed 'device_5_glove_data_action_3.csv' to 'SHIELD373.csv'
# Renamed 'device_5_glove_data_action_30.csv' to 'SHIELD374.csv'
# Renamed 'device_5_glove_data_action_31.csv' to 'SHIELD375.csv'
# Renamed 'device_5_glove_data_action_32.csv' to 'SHIELD376.csv'
# Renamed 'device_5_glove_data_action_33.csv' to 'SHIELD377.csv'
# Renamed 'device_5_glove_data_action_34.csv' to 'SHIELD378.csv'
# Renamed 'device_5_glove_data_action_35.csv' to 'SHIELD379.csv'
# Renamed 'device_5_glove_data_action_36.csv' to 'SHIELD380.csv'
# Renamed 'device_5_glove_data_action_37.csv' to 'SHIELD381.csv'
# Renamed 'device_5_glove_data_action_38.csv' to 'SHIELD382.csv'
# Renamed 'device_5_glove_data_action_39.csv' to 'SHIELD383.csv'
# Renamed 'device_5_glove_data_action_4.csv' to 'SHIELD384.csv'
# Renamed 'device_5_glove_data_action_40.csv' to 'SHIELD385.csv'
# Renamed 'device_5_glove_data_action_41.csv' to 'SHIELD386.csv'
# Renamed 'device_5_glove_data_action_42.csv' to 'SHIELD387.csv'
# Renamed 'device_5_glove_data_action_43.csv' to 'SHIELD388.csv'
# Renamed 'device_5_glove_data_action_44.csv' to 'SHIELD389.csv'
# Renamed 'device_5_glove_data_action_45.csv' to 'SHIELD390.csv'
# Renamed 'device_5_glove_data_action_46.csv' to 'SHIELD391.csv'
# Renamed 'device_5_glove_data_action_47.csv' to 'SHIELD392.csv'
# Renamed 'device_5_glove_data_action_48.csv' to 'SHIELD393.csv'
# Renamed 'device_5_glove_data_action_49.csv' to 'SHIELD394.csv'
# Renamed 'device_5_glove_data_action_5.csv' to 'SHIELD395.csv'
# Renamed 'device_5_glove_data_action_50.csv' to 'SHIELD396.csv'
# Renamed 'device_5_glove_data_action_6.csv' to 'SHIELD397.csv'
# Renamed 'device_5_glove_data_action_7.csv' to 'SHIELD398.csv'
# Renamed 'device_5_glove_data_action_8.csv' to 'SHIELD399.csv'
# Renamed 'device_5_glove_data_action_9.csv' to 'SHIELD400.csv'
